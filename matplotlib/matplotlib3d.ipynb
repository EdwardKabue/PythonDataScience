# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.pd.read_csv("/home/code7/datascience/pandas/survey_results_public.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-07fe773b3afc> in <module>
# ----> 1 df.pd.read_csv("/home/code7/datascience/pandas/survey_results_public.csv")
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("/home/code7/datascience/matplotlib/england-premier-league-matches-2018-to-2019-stats.csv", parse_dates=True)

# %%
#Plot 3-D graph
ax = plt.axes(projection='3d')
ax.scatter(df.index,df["total_goal_count"], df["attendance"])
ax.set_xlabel("Index")
ax.set_ylabel("Goal count")
ax.set_zlabel("Attendance")
plt.show()
